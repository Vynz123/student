# %% [markdown]
# ---
# layout: post
# title: Cb 2021
# description:
# toc: true
# comments: true
# categories: [5.A, C4.1]
# courses: { csse: {week: 1}, csp: {week: 28, categories: [6.B]}, csa: {week: 1} }
# ---

# %% [markdown]
# # My Score:
#
# I scored a 59/70,
# skipping the last 6 questions due to time
#
# # Analysis
#
# So far for a 1 hour time period this is the best i've ever scored. My old exams were a 59/67(using 3 hours). This is a signifcant improvemnt time wise.
#
# Reasons for improvement:
#
# - Independent Research on these various topics like the internet, digital divide etc.
# - Learned more about binary, and RGB which i lacked in before.
#
#
# # Corrections:
#
# ## 15: Consider the following procedure.
#
# Procedure Call	Explanation
# drawLine(x1, y1, x2, y2)	Draws a line segment on a coordinate grid with endpoints at coordinates (x1, y1) and (x2, y2)
# The drawLine procedure is to be used to draw the following figure on a coordinate grid.
#
# The figure presents a graph with 5 line segments in a coordinate grid with the origin labeled O. The horizontal axis is labeled x, and the numbers 1 through 6 are indicated. The vertical axis is labeled y, and the numbers 1 through 5 are indicated. The coordinates of the 5 line segments are as follows. Line segment 1 has endpoints at coordinates 1 comma 0 and 1 comma 1. Line segment 2 has endpoints at coordinates 2 comma 0 and 2 comma 2. Line segment 3 has endpoints at coordinates 3 comma 0 and 3 comma 3. Line segment 4 has endpoints at coordinates 4 comma 0 and 4 comma 4. Line segment 5 has endpoints at coordinates 5 comma 0 and 5 comma 5.
# Which of the following code segments can be used to draw the figure?
#
# My Answer: B Correct Answer A:
#
# Reason for missing:
#
# Mixed up which value got added by len. I put the X value got added when it was supposed to be the y value.
#
#
# ## 37: In the following code segment, assume that the variable n has been initialized with an integer value.
#
# This figure presents a block of code that consists of 10 lines. Throughout the code there are nested blocks of code, as follows. [Begin Block] Line 1: IF [begin block] n ˃ 10 [end block] [Begin Block] [Begin Block] Line 2: IF [begin block] n ˃ 100 [end block] [Begin Block] Line 3: [begin block] DISPLAY [begin block] “artichoke” [end block] [end block] [End Block] Line 4: ELSE [Begin Block] Line 5: [begin block] DISPLAY [begin block] “broccoli” [end block] [end block] [end block] [end block] [End Block] Line 6: ELSE [Begin Block] [Begin Block] Line 7: IF [begin block] n ˃ 100 [end block] [Begin Block] Line 8: [begin block] DISPLAY [begin block] “carrot” [end block] [end block] [End Block] Line 9: ELSE [Begin Block] Line 10: [begin block] DISPLAY [begin block] “daikon” [end block] [end block] [End Block] [End Block] [End Block] [End Block]
# Which of the following is NOT a possible value displayed by the program?
# Responses
#
#
# MY answer: A Correct Answer: C
#
# Reason for Missing:
#
# Mixed up reading my > and < signs and flipped the response I was supposed to do.In the code if n was greater than 100 then artichoke would work, and its inital condition of n> 10 also works. Hwoever for carrot it said n>100, but its inital condition is n is not greater than 10 so it cannot work.
#
#
# ## 41: An online gaming company is introducing several new initiatives to encourage respectful communication between players of online games. Which of the following best describes a solution that uses crowdsourcing?
#
# My Answer: D, Correct Answer A:
#
# Reason for Missing:
# Crowdsourcing is the practice of using input or information obtained from a large number of people via the Internet. In this case, input on a player is provided by other players of the game. Therefore A works, but D doesn't acomplish this goal and instead just reduced disrespect.
#
# ## 46: A large spreadsheet contains the following information about local restaurants. A sample portion of the spreadsheet is shown below.
#
# A
# Restaurant Name	B
# Price Range	C
# Number of
# Customer Ratings	D
# Average
# Customer Rating	E
# Accepts
# Credit Cards
# 1	Joey Calzone’s Pizzeria	lo	182	3.5	false
# 2	78th Street Bistro	med	41	4.5	false
# 3	Seaside Taqueria	med	214	4.5	true
# 4	Delicious Sub Shop II	lo	202	4.0	false
# 5	Rustic Farm Tavern	hi	116	4.5	true
# 6	ABC Downtown Diner	med	0	-1.0	true
# In column B, the price range represents the typical cost of a meal, where "lo" indicates under $10, "med" indicates $11 to $30, and "hi" indicates over $30.
# In column D, the average customer rating is set to -1.0 for restaurants that have no customer ratings.
#
# My Answer: B, Correct Answer D:
#
#
# Reasoning: Any arrangement of these three steps will pinpoint the right restaurant. Sequence II is effective. Initially, screening by the number of ratings will eliminate those without any. Subsequently, arranging by rating will place the highest-rated establishments at the forefront. Lastly, filtering by payment method will exclude those not accepting credit cards. Therefore all three work, and not just 1 and 2.
#
#
# ## 47: A large spreadsheet contains the following information about local restaurants. A sample portion of the spreadsheet is shown below.
#
# A
# Restaurant Name	B
# Price Range	C
# Number of
# Customer Ratings	D
# Average
# Customer Rating	E
# Accepts
# Credit Cards
# 1	Joey Calzone’s Pizzeria	lo	182	3.5	false
# 2	78th Street Bistro	med	41	4.5	false
# 3	Seaside Taqueria	med	214	4.5	true
# 4	Delicious Sub Shop II	lo	202	4.0	false
# 5	Rustic Farm Tavern	hi	116	4.5	true
# 6	ABC Downtown Diner	med	0	-1.0	true
# In column B, the price range represents the typical cost of a meal, where "lo" indicates under $10, "med" indicates $11 to $30, and "hi" indicates over $30.
# In column D, the average customer rating is set to -1.0 for restaurants that have no customer ratings.
#
#
# My Answer: A, Correct Answer B:
#
# Reason for Missing,
#
# The expression should always evaluate to fals ebecause it cannot be equal to both things at one time, therefore the result of this is too, Therefore it must be a AND statement and not a OR statement.
#
#
# ## 55: A code segment is intended to transform the list utensils so that the last element of the list is moved to the beginning of the list.
#
# For example, if utensils initially contains  ["fork", "spoon", "tongs", "spatula", "whisk"], it should contain ["whisk", "fork", "spoon", "tongs", "spatula"] after executing the code segment.
#
# Which of the following code segments transforms the list as intended?
#
#
# My Answer: A, Correct Answer C:
#
# My answer removes then appends which makes the list the exact same while the correct answer does the intended job properly.

# %% [markdown]
# # Takeaways:
#
# I learned the skills I am lacking and learned more about the skills I am confident infor the AP exam. Following a study regime, and guide I strongly believe I can aim to get a 5 on the AP Exam by following the material we have learned in class.
#
#
# # How I plan to Study?
#
# I plan to study by doing more practice tests
# more practice problems
# reviewing the material and making sure I understand it
# Doing consistent practice to memorize all the neccsary material before ap exam season.
